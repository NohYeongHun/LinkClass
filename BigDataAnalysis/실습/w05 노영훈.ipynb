# %% [markdown]
# # 노영훈
# ## 2021년 4월 1일

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = [10,11,12,13,14]
data_test = pd.Series(data)
data_test
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
sr1 = pd.Series(data, index=[1000,1001,1002,1003,1004])
print(sr1)
# Out:
# 1000    1반
# 1001    2반
# 1002    3반
# 1003    4반
# 1004    5반
# dtype: object

# %%
data = ['1반','2반','3반','4반','5반',]
sr2 = pd.Series(data, index=[10,20,30,40,50])
print(sr2)
sr3 = pd.Series(data, index=['월','화','수','목','금'])
print(sr3)
# Out:
# 10    1반
# 20    2반
# 30    3반
# 40    4반
# 50    5반
# dtype: object
# 월    1반
# 화    2반
# 수    3반
# 목    4반
# 금    5반
# dtype: object

# %%
sr3[0:4]
# Out:
# 월    1반
# 화    2반
# 수    3반
# 목    4반
# dtype: object

# %%
print(sr2[10])
print(sr3['수'])
print(sr2[20])
# Out:
# 1반
# 3반
# 2반

# %%
data_dic ={
    'year':[2018,2019,2020],
    'sales': [350,480, 1099]
}
data_dic
# Out:
# {'year': [2018, 2019, 2020], 'sales': [350, 480, 1099]}

# %%
df1 = pd.DataFrame(data_dic)
df1
# Out:
#    year  sales
# 0  2018    350
# 1  2019    480
# 2  2020   1099

# %%
data2 = ['1반','2반','3반','4반','5반']

# %%
df3 = pd.DataFrame([[89.2, 92.5, 90.8], [92.8, 89.9, 95.2]], index = ['중간고사', '기말고사'], columns = data2[0:3])
df3
# Out:
#         1반    2반    3반
# 중간고사  89.2  92.5  90.8
# 기말고사  92.8  89.9  95.2

# %%
df3.head(2)
# Out:
#         1반    2반    3반
# 중간고사  89.2  92.5  90.8
# 기말고사  92.8  89.9  95.2

# %%
df3.tail(2)
# Out:
#         1반    2반    3반
# 중간고사  89.2  92.5  90.8
# 기말고사  92.8  89.9  95.2

# %%
df3['1반']
# Out:
# 중간고사    89.2
# 기말고사    92.8
# Name: 1반, dtype: float64

# %%
data3 = ['학번','이름','중간고사','기말고사']
data_df = [['20201101', 'Hong', '90', '95'], ['20201102', 'Kim', '93', '94'], ['20201103', 'Lee', '87', '97'],['20201104','Yun','90','95'], ['20201105','Sun','85','90']]
df3 = pd.DataFrame(data_df, columns = data3[0:4])
df3
# Out:
#          학번    이름 중간고사 기말고사
# 0  20201101  Hong   90   95
# 1  20201102   Kim   93   94
# 2  20201103   Lee   87   97
# 3  20201104   Yun   90   95
# 4  20201105   Sun   85   90

# %%
df3.head(3)
# Out:
#          학번    이름 중간고사 기말고사
# 0  20201101  Hong   90   95
# 1  20201102   Kim   93   94
# 2  20201103   Lee   87   97

# %%
df3.tail(2)
# Out:
#          학번   이름 중간고사 기말고사
# 3  20201104  Yun   90   95
# 4  20201102  Sun   85   90

# %%
df3.to_csv('./score.csv')

# %%
df4 = pd.read_csv('score.csv',index_col=0)
df4
# Out:
#          학번    이름  중간고사  기말고사
# 0  20201101  Hong    90    95
# 1  20201102   Kim    93    94
# 2  20201103   Lee    87    97
# 3  20201104   Yun    90    95
# 4  20201102   Sun    85    90

# %%
plt.plot([10,20,30,40])

# %%
plt.plot([11,12,13,14],[10,20,30,40])

# %%
plt.title('graph example')
plt.plot([10,20,30,40], color='r', linestyle ='--', label='asc')
plt.plot([40,30,20,10], ls=':', label='asc') # ls == linestyle
plt.legend(loc=9)
plt.xlabel('index')
plt.ylabel('value')
plt.show()

# %%
plt.title('marker example')
plt.plot([10,20,30,40], 'r.', label ='circle')
plt.plot([40,30,20,10], 'g^--', label ='triangle up')
plt.legend(loc=8) # 범례 표시
plt.show()

# %%
y1 = [350, 410, 520, 695]
y2 = [200, 250, 385, 350]
x = range(len(y1))

# %%
plt.bar(x, y2, color='r')
plt.show()

# %%
plt.bar(x, y1, width=0.7, color = 'blue')
plt.show()

# %%
plt.bar(x, y1, width=0.7, color='blue')
plt.bar(x, y2, width=0.7, color='red', bottom=y1)
plt.title('Quarterly sales')
plt.xlabel('Quarters') # x축 레이블
plt.ylabel('sales')
xLabel = ['first', 'second', 'third', 'fourth'] # 눈금 이름 리스트 생성
plt.xticks(x, xLabel, fontsize = 10) # 바 차트의 x 축 눈금 이름 설정
plt.legend(['chairs', 'desks']) # 범례 설정
plt.show()

# %%
# 4월 1일의 기온 변화를 그래프로 그리기
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []
for row in data:
    if row[-1] !='':
        result.append(float(row[-1]))
print(result)
f.close()
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
print(row)
print(len(result))
# Out:
# ['2019-01-17', '108', '-0.3', '-3.2', '4']
# 39463

# %%
plt.plot(result,'r')
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.plot(result, 'r')
plt.show()

# %%
date = '1907-10-01'
print(date.split('-'))
print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# ['1907', '10', '01']
# 1907
# 10
# 01

# %%
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []
for row in data:
    if row[-1] !='':
        if row[0].split('-')[1] == '08':
            result.append(float(row[-1]))
plt.plot(result, 'hotpink')
plt.show()

# %%
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []
for row in data:
    if row[-1] !='':
        if row[0].split('-')[1] =='04' and row[0].split('-')[2] == '01':
            result.append(float(row[-1]))
plt.plot(result, 'skyblue')
plt.show()

# %%
f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data:
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('-')[0]) :
            if row[0].split('-')[1] == '04' and row[0].split('-')[2] == '01':
                high.append(float(row[-1]))
                low.append(float(row[-2]))

plt.rc('font', family='Malgun Gothic')
plt.title('4월 1일의 기온 변화 그래프')
plt.rcParams['axes.unicode_minus']=False
plt.plot(high,'hotpink', label ='high')
plt.plot(low, 'skyblue', label ='row')
plt.legend(loc = 'upper right')
plt.show()

# %%
f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data:
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('-')[0]) :
            if row[0].split('-')[1] == '02' and row[0].split('-')[2] == '01':
                high.append(float(row[-1]))
                low.append(float(row[-2]))

plt.rc('font', family='Malgun Gothic')
plt.title('2월 1일의 기온 변화 그래프')
plt.rcParams['axes.unicode_minus']=False
plt.plot(high,'hotpink', label ='high')
plt.plot(low, 'skyblue', label = 'row')
plt.legend(loc= 'upper right')
plt.show()

# %%
import random
print(random.randint(1,6))
# Out:
# 3

# %%
dice = []
for i in range(5) :
    dice.append(random.randint(1,6))
print(dice)
plt.xlim(1,6)
plt.hist(dice, bins=6)
plt.show()
# Out:
# [6, 2, 6, 1, 4]

# %%
dice = []
for i in range(100):
    dice.append(random.randint(1,6))
print(dice)

plt.hist(dice, bins=6)
plt.show()
# Out:
# [2, 3, 1, 2, 4, 6, 3, 1, 1, 6, 6, 1, 2, 1, 4, 5, 5, 2, 4, 3, 5, 5, 4, 6, 1, 1, 6, 2, 5, 3, 1, 5, 5, 4, 1, 4, 3, 5, 3, 3, 5, 4, 2, 4, 1, 4, 1, 6, 6, 2, 5, 3, 6, 6, 3, 5, 5, 2, 3, 2, 1, 2, 4, 6, 6, 2, 5, 5, 1, 1, 1, 5, 5, 6, 1, 3, 2, 1, 4, 5, 5, 5, 3, 1, 2, 3, 5, 3, 4, 6, 1, 2, 4, 2, 2, 6, 4, 1, 3, 2]

# %%
dice = []
for i in range(1000):
    dice.append(random.randint(1,6))
print(dice)

plt.hist(dice, bins=6)
plt.show()
# Out:
2, 5, 3, 3, 5, 6, 3, 2, 5, 4, 4, 3, 1, 3, 1, 3, 1, 3, 1, 2, 6, 2, 1, 3, 3, 2, 1, 4, 4, 2, 4, 5, 1, 3, 4, 4, 6, 6, 6, 2, 4, 2, 5, 6, 6, 2, 2, 1, 4, 3, 6, 3, 2, 1, 3, 4, 4, 4, 6, 4, 2, 3, 5, 6, 2, 5, 4, 3, 3, 1, 5, 6, 5, 5, 6, 5, 3, 4, 1, 5, 2, 5, 1, 3, 2, 4, 3, 4, 6, 6, 3, 6, 1, 5, 3, 4, 6, 6, 3, 6, 6, 5, 2, 5, 2, 4, 2, 6
# ...

# %%
dice = []
for i in range(100000):
    dice.append(random.randint(1,6))
print(dice)

plt.hist(dice, bins=6)
plt.show()
# Out:
# [4, 1, 1, 1, 1, 2, 2, 4, 5, 3, 5, 2, 6, 2, 6, 4, 2, 4, 2, 3, 5, 2, 5, 3, 6, 4, 6, 5, 4, 1, 1, 6, 1, 3, 3, 1, 2, 3, 3, 5, 6, 3, 3, 4, 3, 3, 2, 1, 1, 3, 1, 4, 4, 3, 4, 5, 3, 4, 1, 5, 3, 2, 2, 3, 3, 1, 5, 5, 5, 6, 1, 2, 4, 1, 1, 5, 6, 5, 1, 3, 6, 1, 3, 3, 1, 1, 4, 6, 3, 3, 4, 2, 3, 5, 5, 6, 6, 1, 2, 1, 4, 5, 1, 2, 4, 3, 1, 1, 3, 5, 4, 3, 4, 5, 2, 5, 5, 2, 3, 6, 3, 3, 5, 2, 2, 6, 5, 2, 5, 5, 6, 5, 3, 1, 6, 4, 6, 1, 3, 1, 5, 6, 3, 6, 5, 4, 3, 4, 4, 3, 6, 4, 1, 5, 1, 3, 4, 1, 3, 4, 4, 3, 1, 1, 2, 6, 2, 2, 2, 6, 2, 3, 1, 4, 4, 3, 4, 6, 1, 3, 4, 5, 1, 2, 3, 3, 1, 5, 1, 6, 5, 5, 2, 6, 1, 2, 5, 1, 2, 2, 5, 2, 2, 5, 3, 3, 4, 3, 2, 4, 4, 5, 1, 4, 4, 4, 1, 2, 2, 2, 5, 5, 6, 2, 3, 1, 4, 6, 3, 2, 2, 2, 2, 1, 1, 5, 3, 3, 3, 5, 3, 4, 3, 6, 5, 4, 3, 1, 5, 4, 5, 3, 6, 6, 1, 4, 1, 4, 1, 3, 1, 2, 4, 2, 5, 5, 4, 5, 4, 6, 3, 2, 6, 1, 1, 4, 4, 3, 4, 6, 1, 1, 2, 6, 6, 3, 2, 2, 1, 4, 2, 5, 4, 5, 5, 6, 1, 3, 2, 5, 1, 2, 6, 5, 1, 2, 6, 3, 3, 5, 1, 2, 5, 1, 1, 6, 1, 1, 2, 4, 4, 5, 2, 4, 6, 2, 4, 5, 5, 5, 4, 6, 1
# ...

# %%
dice = []
for i in range(1000000):
    dice.append(random.randint(1,6))
print(dice)

plt.hist(dice, bins=6)
plt.show()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))

plt.hist(result, bins = 100, color ='r')
plt.show()

# %%
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []

for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))

plt.hist(aug, bins = 100, color ='r')
plt.show()

# %%
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

plt.hist(aug, bins = 100, color = 'r', label ='Aug')
plt.hist(jan, bins = 100, color = 'b', label ='Jan')
plt.legend()
plt.show()

# %%
# 인천 최고 온도 및 최저 온도에 대한 선 그래프를 작성하시오.
f = open('Incheon.csv')
data = csv.reader(f)
next(data)
min = []
max = []
for row in data:
    month = row[0].split('-')[1]
    if row[] !='':
        
            
plt.title('graph example')
plt.plot([10,20,30,40], color='r', linestyle ='--', label='asc')
plt.plot([40,30,20,10], ls=':', label='asc') # ls == linestyle
plt.legend(loc=9)
plt.xlabel('index')
plt.ylabel('value')
plt.show()

# %%
# 2018년 인천의 최저온도에 대한 히스토그램을 작성하시오
df = pd.read_csv('Incheon.csv')
list_Incheon = []
for i in range(len(df)):
    if df['날짜'].str[0:4][i] == 2018:
        list_incheon.append(df['최저기온'][i])

# %%
list_incheon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-224-8f63ea4f9861> in <module>
# ----> 1 list_incheon
#
# NameError: name 'list_incheon' is not defined

# %%
plt.hist(list_incheon, bins = 50, color = 'r', label ='Incheon')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-223-ad08a260fd3f> in <module>
# ----> 1 plt.hist(list_incheon, bins = 50, color = 'r', label ='Incheon')
#       2 plt.legend()
#       3 plt.show()
#
# NameError: name 'list_incheon' is not defined

# %%
# 윷놀이(도, 개, 걸, 윷, 모) 대한 히스토그램 작성
# 데이터 100 ~ 10000개
import random
rand_sring = "도개걸윷모"
rand_list = []
for i in range(100):
    num = random.choice(rand_string)
    rand_list.append(num)
plt.hist(rand_list, bins=5)
plt.show()

# %%
rand_sring = "도개걸윷모"
rand_list = []
for i in range(1000):
    # random.choice 문자열 랜덤
    num = random.choice(rand_string)
    rand_list.append(num)
plt.hist(rand_list, bins=5)
plt.show()

# %%
rand_sring = "도개걸윷모"
rand_list = []
for i in range(10000):
    num = random.choice(rand_string)
    rand_list.append(num)
plt.hist(rand_list, bins=5)
plt.show()

# %%
# 판다스로 csv파일 생성
df1 = pd.read_csv('customer_master.csv',encoding='utf-8')
df2 = pd.read_csv('item_master.csv',encoding='utf-8')
df3 = pd.read_csv('seoul.csv',encoding='utf-8')
df4 = pd.read_csv('transaction_1.csv',encoding='utf-8')
df5 = pd.read_csv('transaction_detail_1.csv',encoding='utf-8')

# %%
df1
# Out:
#      customer_id customer_name registration_date                        email  \
# 0       IK152942           김서준   2019-01-01 0:25  hirata_yuujirou@example.com
# 1       TS808488           김예준   2019-01-01 1:13    tamura_shiori@example.com
# 2       AS834628           김도윤   2019-01-01 2:00      hisano_yuki@example.com
# 3       AS345469           김시우   2019-01-01 4:48   tsuruoka_kaoru@example.com
# 4       GD892565           김주원   2019-01-01 4:54   oouchi_takashi@example.com
# ...          ...           ...               ...                          ...
# 4995    AS677229           정우석  2019-07-31 16:52    hirayama_risa@example.com
# 4996    HD758694           정영훈  2019-07-31 19:09  nakahara_mahiru@example.com
# 4997    PL538517           정준기  2019-07-31 19:30      tabata_yuu1@example.com
# 4998    OA955088           정도형  2019-07-31 22:32  setouchi_hikaru@example.com
# 4999    HI349563           정지석  2019-07-31 22:49      horii_kanji@example.com
#
# ...

# %%
df2
# Out:
#   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000
# 3    S004      PC-D      180000
# 4    S005      PC-E      210000

# %%
df3
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      1907-10-01  108     13.5      7.9     20.7
# 1      1907-10-02  108     16.2      7.9     22.0
# 2      1907-10-03  108     16.2     13.1     21.3
# 3      1907-10-04  108     16.5     11.2     22.0
# 4      1907-10-05  108     17.6     10.9     25.4
# ...           ...  ...      ...      ...      ...
# 40216  2019-01-13  108      1.2     -3.0      7.6
# 40217  2019-01-14  108      1.4     -2.4      5.3
# 40218  2019-01-15  108     -1.7     -7.2      2.6
# 40219  2019-01-16  108     -5.2    -10.1     -1.1
# 40220  2019-01-17  108     -0.3     -3.2      4.0
#
# [40221 rows x 5 columns]

# %%
df4
# Out:
#      transaction_id   price         payment_date customer_id
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865
# ...             ...     ...                  ...         ...
# 4995    T0000005108  210000  2019-06-15 02:42:41    HD315748
# 4996    T0000005109  150000  2019-06-15 03:36:16    HI215420
# 4997    T0000005110   50000  2019-06-15 03:44:06    IK880102
# 4998    T0000005111  210000  2019-06-15 04:14:06    IK074758
# 4999    T0000005112   50000  2019-06-15 04:42:38    HD444151
#
# [5000 rows x 4 columns]

# %%
df5
# Out:
#       detail_id transaction_id item_id  quantity
# 0             0    T0000000113    S005         1
# 1             1    T0000000114    S001         1
# 2             2    T0000000115    S003         1
# 3             3    T0000000116    S005         1
# 4             4    T0000000117    S002         2
# ...         ...            ...     ...       ...
# 4995       4995    T0000004865    S003         1
# 4996       4996    T0000004866    S001         3
# 4997       4997    T0000004867    S001         3
# 4998       4998    T0000004868    S005         1
# 4999       4999    T0000004869    S003         1
#
# [5000 rows x 4 columns]
