# %%
a=vector([1,1,1])
b=vector([-1,-1,-1])
c=vector([2,2,2])
2*a-4*b+5*c
# Out:
# (16, 16, 16)

# %%
[3*x-2 for x in range(0,10) if x%2==1]
# Out:
# [1, 7, 13, 19, 25]

# %%
[3*x^2+1 for x in range(0,10) if x%2==0]
# Out:
# [1, 13, 49, 109, 193]

# %%
f(x)=x^4+x^2
f(3)
# Out:
# 90

# %%
f=-x^2+4*x+1
plot(f,x,0,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f,x,(0,5),fill="axis")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f=-x^2+4*x+1
plot(f,x,0,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
integral(f,x,0,5)
# Out:
# 40/3

# %%
revolution_plot3d(f,(x,0,5),parallel='x')
# Out:
# Graphics3d Object

# %%
integral(pi*f^2,x,0,5)
# Out:
# 190/3*pi

# %%
Graph({0:[1,2,3,4],3:[5,6],4:[7,8,9]}).plot()
# Out:
# Graphics object consisting of 20 graphics primitives
